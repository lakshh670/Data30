# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %% [markdown]
# ## Distribution plot for numerical variables

# %%
sns.distplot(df['Age'],rug=True,bins=10)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_17068\1054602903.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],rug=True,bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'],bins=10)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_17068\4051194859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'],bins=10)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'],bins=10)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_17068\349951893.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],bins=10)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %% [markdown]
# ## Visualization for Categorical Variables

# %%
df.groupby('Sex').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Violin Plots

# %%
sns.violinplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(data=df,y='Age',x='HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(data=df,y='Age',x='HeartDisease',hue='Sex')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(data=df,y='Sex',x='HeartDisease')
# in this plot we can see that chances of heart disease is more in males then in females.
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# ## Correlations

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(data=df,x='Age',y='MaxHR')

# %%
sns.jointplot(data=df,x='Age',y='MaxHR',kind='reg')

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df)
# it makes joint plot b/w every pair

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\GFG\\Projects\\Heart_Data_Analysis'
